# %% [markdown]
# <a id="1"></a>
# # <p style="padding:15px;background-color:#0F333D;margin:0;color:#D4FFCA;font-family:Verdana,sans-serif;font-size:9-0%;text-align:center;border-radius: 5px 5px;overflow:hidden;font-weight:900">Network Anomaly Detection</p>

# %% [markdown]
# <div style="background-color:#D4FFCA; padding:30px; font-size:14px; border-radius: 5px 5px;">
#
# **🦠Goal:**
#
# The number of cyber-attacks is becoming increasingly sophisticated and difficult to detect, which can result in significant financial and reputational losses for organisations. The aim of this project is to develop an effective network anomaly detection system to identify suspicious activities and attacks on the network using Machine Learning techniques, such as Isolation Forest or DBScan, in order to improve security and prevent further potential attacks.

# %% [markdown]
# <div style="background-color:#D4FFCA; padding:30px; font-size:14px; border-radius: 5px 5px;">
#
# **📃 Data:**
#
# | No. | Kolom                        | Deskripsi                                                                                  | Tipe Data |
# |-----|------------------------------|--------------------------------------------------------------------------------------------|-----------|
# | 1   | duration                     | Durasi koneksi (dalam detik)                                                               | int64     |
# | 2   | protocol_type                | Jenis protokol yang digunakan (misalnya TCP, UDP, ICMP)                                    | object    |
# | 3   | service                      | Jenis layanan pada tujuan koneksi (misalnya HTTP, FTP, SMTP)                               | object    |
# | 4   | flag                         | Status koneksi (misalnya SF, S0, REJ)                                                      | object    |
# | 5   | src_bytes                    | Jumlah byte dari sumber ke tujuan                                                          | int64     |
# | 6   | dst_bytes                    | Jumlah byte dari tujuan ke sumber                                                          | int64     |
# | 7   | land                         | Apakah koneksi memiliki alamat IP sumber dan tujuan yang sama                              | int64     |
# | 8   | wrong_fragment               | Jumlah fragmen salah                                                                       | int64     |
# | 9   | urgent                       | Jumlah paket mendesak                                                                      | int64     |
# | 10  | hot                          | Jumlah kejadian "hot" pada koneksi                                                         | int64     |
# | 11  | num_failed_logins            | Jumlah upaya login yang gagal                                                               | int64     |
# | 12  | logged_in                    | Status login (1 jika berhasil, 0 jika tidak)                                                | int64     |
# | 13  | num_compromised              | Jumlah kejadian kompromi pada sistem                                                      | int64     |
# | 14  | root_shell                   | Apakah root shell diakses (1 jika ya, 0 jika tidak)                                         | int64     |
# | 15  | su_attempted                 | Jumlah upaya super user                                                                    | int64     |
# | 16  | num_root                     | Jumlah akses root                                                                          | int64     |
# | 17  | num_file_creations           | Jumlah pembuatan file                                                                      | int64     |
# | 18  | num_shells                   | Jumlah shell yang diakses                                                                  | int64     |
# | 19  | num_access_files             | Jumlah akses file                                                                          | int64     |
# | 20  | num_outbound_cmds            | Jumlah perintah keluar yang dijalankan                                                     | int64     |
# | 21  | is_host_login                | Apakah login dilakukan dari host (1 jika ya, 0 jika tidak)                                  | int64     |
# | 22  | is_guest_login               | Apakah login dilakukan sebagai guest (1 jika ya, 0 jika tidak)                              | int64     |
# | 23  | count                        | Jumlah koneksi ke host yang sama dalam waktu dua detik sebelumnya                          | int64     |
# | 24  | srv_count                    | Jumlah koneksi ke layanan yang sama dalam waktu dua detik sebelumnya                       | int64     |
# | 25  | serror_rate                  | Persentase koneksi dengan kesalahan SYN                                                    | float64   |
# | 26  | srv_serror_rate              | Persentase koneksi ke layanan yang sama dengan kesalahan SYN                               | float64   |
# | 27  | rerror_rate                  | Persentase koneksi dengan kesalahan REJ                                                    | float64   |
# | 28  | srv_rerror_rate              | Persentase koneksi ke layanan yang sama dengan kesalahan REJ                               | float64   |
# | 29  | same_srv_rate                | Persentase koneksi ke layanan yang sama                                                    | float64   |
# | 30  | diff_srv_rate                | Persentase koneksi ke layanan yang berbeda                                                 | float64   |
# | 31  | srv_diff_host_rate           | Persentase koneksi ke host yang berbeda pada layanan yang sama                             | float64   |
# | 32  | dst_host_count               | Jumlah koneksi ke host tujuan                                                              | int64     |
# | 33  | dst_host_srv_count           | Jumlah koneksi ke layanan yang sama pada host tujuan                                       | int64     |
# | 34  | dst_host_same_srv_rate       | Persentase koneksi ke layanan yang sama pada host tujuan                                   | float64   |
# | 35  | dst_host_diff_srv_rate       | Persentase koneksi ke layanan yang berbeda pada host tujuan                                | float64   |
# | 36  | dst_host_same_src_port_rate  | Persentase koneksi ke layanan yang sama dari port sumber yang sama                         | float64   |
# | 37  | dst_host_srv_diff_host_rate  | Persentase koneksi ke host yang berbeda pada layanan yang sama pada host tujuan            | float64   |
# | 38  | dst_host_serror_rate         | Persentase koneksi ke host tujuan dengan kesalahan SYN                                     | float64   |
# | 39  | dst_host_srv_serror_rate     | Persentase koneksi ke layanan yang sama pada host tujuan dengan kesalahan SYN              | float64   |
# | 40  | dst_host_rerror_rate         | Persentase koneksi ke host tujuan dengan kesalahan REJ                                     | float64   |
# | 41  | dst_host_srv_rerror_rate     | Persentase koneksi ke layanan yang sama pada host tujuan dengan kesalahan REJ              | float64   |
# | 42  | class                        | Label kelas koneksi (Normal atau Anomalous)                                                | object    |
#
# Keterangan:
# - TCP: Protokol andal untuk pengiriman data.
# - UDP: Protokol cepat tanpa jaminan keandalan.
# - ICMP: Protokol untuk pesan kesalahan jaringan.
# - HTTP: Protokol untuk mengakses situs web.
# - FTP: Protokol untuk transfer file.
# - SMTP: Protokol untuk mengirim email.
# - SF: Koneksi berhasil tanpa kesalahan.
# - S0: Koneksi dimulai tapi belum selesai.
# - REJ: Koneksi ditolak.
# - Hot: Aktivitas mencurigakan.
# - Shell: Antarmuka baris perintah.
# - SYN: Paket untuk memulai koneksi.
# - REJ: Koneksi atau permintaan ditolak.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import plotly.graph_objs    as go
import plotly.express       as px
import plotly.express       as px
import plotly.graph_objects as go
import matplotlib.colors    as mcolors

# %%
from   pyforest          import *
from   tqdm              import tqdm
from   sklearn.manifold  import TSNE
from   plotly.offline    import iplot
from   keras.models      import Model
from   scipy             import stats
from   sklearn.cluster   import DBSCAN
from   termcolor         import colored
from   sklearn           import metrics
from   eif               import iForest
from   tabulate          import tabulate
from   plotly.subplots   import make_subplots
from   sklearn.metrics   import accuracy_score
from   datetime          import date, timedelta
from   pandas.api.types  import is_numeric_dtype
from   sklearn.neighbors import LocalOutlierFactor
from   sklearn.metrics   import adjusted_rand_score
from   sklearn.metrics   import classification_report
from   sklearn.metrics   import make_scorer, f1_score
from   keras.layers      import Input, Dense, BatchNormalization       
from   sklearn.metrics   import silhouette_score, calinski_harabasz_score

# %%
# kumpulan warna palet
colors     = ["#0F333D", "#D4FFCA", "#A9D2C2", "#4A6D76", "#8FBFAC"]
my_palette = sns.color_palette(["#0F333D", "#D4FFCA", "#A9D2C2", "#4A6D76", "#8FBFAC"])
cmap       = mcolors.ListedColormap(colors)

sns.palplot(sns.color_palette(colors))
plt.title('Warna Palette Utama')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:15px;background-color:#0F333D;margin:0;color:#D4FFCA;font-family:Verdana,sans-serif;font-size:9-0%;text-align:center;border-radius: 5px 5px;overflow:hidden;font-weight:900">2. Data Understanding</p>

# %%
train = pd.read_csv('C:/Users/ASUS/kode/projek/19. Anomaly Detection/latihan/Network_Anomaly.csv')

# %%
train = pd.DataFrame(train)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15968 entries, 0 to 15967
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     15968 non-null  int64
#  1   protocol_type                15968 non-null  object
#  2   service                      15968 non-null  object
#  3   flag                         15968 non-null  object
#  4   src_bytes                    15968 non-null  int64
#  5   dst_bytes                    15968 non-null  int64
#  6   land                         15968 non-null  int64
#  7   wrong_fragment               15968 non-null  int64
#  8   urgent                       15968 non-null  int64
#  9   hot                          15968 non-null  int64
#  10  num_failed_logins            15968 non-null  int64
#  11  logged_in                    15968 non-null  int64
#  12  num_compromised              15968 non-null  int64
# ...

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:15px;background-color:#0F333D;margin:0;color:#D4FFCA;font-family:Verdana,sans-serif;font-size:9-0%;text-align:center;border-radius: 5px 5px;overflow:hidden;font-weight:900">3. Data Preprocessing</p>

# %%
train['class'].value_counts()
# Out:
# class
# normal     13449
# anomaly     2519
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10, 6))

sns.countplot(data = train,
              x    = 'class',
              palette=colors)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
plt.figure(figsize=(20, 6))

sns.heatmap((train.isna().sum()).to_frame(name='').T,
             cmap  = my_palette,
             annot = True,
             fmt   = '0.0f').set_title('Jumlah nilai hilang', fontsize=18)
plt.show()

# %%
train.duplicated().sum()
# Out:
# 0

# %%
numeric_columns   = []
categoric_columns = []

for col in train.columns:
    
    if train[col].dtype == 'object':
        categoric_columns.append(col)
        
    else:
        numeric_columns.append(col)

# %%
output_column     = 'class'
categoric_columns = list(set(categoric_columns) - {output_column})

# %%
categoric_columns
# Out:
# ['flag', 'protocol_type', 'service']

# %%
output_column
# Out:
# 'class'

# %%
# Memeriksa data yang unik dari numerik

unik = train[numeric_columns].nunique()

plt.figure(figsize=(20, 6))
unik.plot(kind='bar', color=colors)
plt.title('Elemen yang Unik dari setiap kolom Numerik')
plt.ylabel('Jumlah')

for i, v in enumerate(unik.values):
                      
    plt.text(i,
             v+1,
             str(v),
             color      ='black',
             fontweight ='bold',
             ha         ='center')
    
plt.show()

# %%
kolom_numerik = ['duration',
                 'src_bytes',
                 'dst_bytes',
                 'hot',
                 'num_compromised',
                 'num_root',
                 'num_file_creations',
                 'count',
                 'srv_count',
                 'dst_host_count',
                 'dst_host_srv_count']

# %%
kolom_numerik2 = ['duration',
                 'hot',
                 'num_compromised',
                 'num_root',
                 'num_file_creations',
                 'count',
                 'srv_count',
                 'dst_host_count',
                 'dst_host_srv_count']

# %%
train.describe()
# Out:
#           duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  15968.00000  1.596800e+04  1.596800e+04  15968.000000    15968.000000
# mean     222.32897  1.003503e+04  4.077410e+03      0.000063        0.008830
# std     1935.34393  1.591394e+05  7.602264e+04      0.007914        0.159018
# min        0.00000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.00000  4.400000e+01  0.000000e+00      0.000000        0.000000
# 50%        0.00000  2.170000e+02  3.260000e+02      0.000000        0.000000
# 75%        0.00000  3.150000e+02  1.579000e+03      0.000000        0.000000
# max    42862.00000  7.665876e+06  5.151385e+06      1.000000        3.000000
#
#         urgent           hot  num_failed_logins     logged_in  \
# count  15968.0  15968.000000       15968.000000  15968.000000
# mean       0.0      0.223948           0.001065      0.602204
# std        0.0      2.349752           0.041108      0.489458
# ...

# %%
# Memeriksa data yang unik seperti id, dll

unik2 = train[categoric_columns].nunique()

plt.figure(figsize=(20, 6))
unik2.plot(kind='bar', color=colors)
plt.title('Elemen yang Unik dari setiap kolom Kategorikal')
plt.ylabel('Jumlah')

for i, v in enumerate(unik2.values):
    plt.text(i,
             v+1,
             str(v),
             color      = 'black',
             fontweight = 'bold',
             ha         = 'center')

plt.show()

# %%
train.head(5)
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp      http   SF        232       8153     0
# 3         0           tcp      http   SF        199        420     0
# 4         0           tcp   private   S0          0          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                 255
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                  15
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    1.00                    0.00
# ...

# %%
train.describe()
# Out:
#           duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  15968.00000  1.596800e+04  1.596800e+04  15968.000000    15968.000000
# mean     222.32897  1.003503e+04  4.077410e+03      0.000063        0.008830
# std     1935.34393  1.591394e+05  7.602264e+04      0.007914        0.159018
# min        0.00000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.00000  4.400000e+01  0.000000e+00      0.000000        0.000000
# 50%        0.00000  2.170000e+02  3.260000e+02      0.000000        0.000000
# 75%        0.00000  3.150000e+02  1.579000e+03      0.000000        0.000000
# max    42862.00000  7.665876e+06  5.151385e+06      1.000000        3.000000
#
#         urgent           hot  num_failed_logins     logged_in  \
# count  15968.0  15968.000000       15968.000000  15968.000000
# mean       0.0      0.223948           0.001065      0.602204
# std        0.0      2.349752           0.041108      0.489458
# ...

# %% [markdown]
# #### Tidak Perlu Handling Outlier
# Hal ini dikarenakan kemungkinan sangat besar bahwa anomali merupakan outlier itu sendiri, sedangkan disini kita ingin detection anomaly.

# %% [markdown]
# ### EDA

# %%
train['class'].value_counts()
# Out:
# class
# normal     13449
# anomaly     2519
# Name: count, dtype: int64

# %%
colors = ['#0F333D',
          '#D4FFCA',
          '#A9D2C2',
          '#4A6D76',
          '#8FBFAC']

# %%
def bar_plot(df, kategorik_vars, target_var):
    cat           =  df[kategorik_vars]
    n             =  len(cat.columns)
    rows          =  n // 2 + n % 2
    cols          =  2
    sns.set(style = "whitegrid", font_scale=1)
    fig, ax       =  plt.subplots(rows, cols, figsize=(20, rows * 5))

    for i in range(rows):
        for j in range(cols):
            index    = i * cols + j
            
            if index < n:
                col  = cat.columns[index]
                palette = sns.color_palette(colors)
                
                sns.countplot(ax=ax[i, j],
                              data=df,
                              x=col,
                              color=colors,
                              hue=target_var,
                              palette=palette)
                
                ax[i, j].set_title(f'Hubungan antara {col} terhadap {target_var}', fontdict={'fontsize': 15})
                ax[i, j].set_xlabel(col)
                ax[i, j].set_ylabel('Count')

    plt.tight_layout()
    plt.show()

# %%
bar_plot(train, categoric_columns, 'class')

# %%
def num_hist_plot(df, numerical_columns, target_var):
    num           =  df[numerical_columns]
    n             =  len(num.columns)
    rows          =  n // 2 + n % 2
    cols          =  2
    sns.set(style = "whitegrid", font_scale=1)
    fig, ax       =  plt.subplots(rows, cols, figsize=(20, rows * 5))

    for i in range(rows):
        for j in range(cols):
            index    = i * cols + j
            
            if index < n:
                col  = num.columns[index]
                palette = sns.color_palette(colors)  # define your palette here
                
                sns.histplot(ax=ax[i, j],
                              data=df,
                              x=col,
                              hue=target_var,
                              palette=palette)
                
                ax[i, j].set_title(f'Distribusi {col} terhadap {target_var}', fontdict={'fontsize': 15})
                ax[i, j].set_xlabel(col)
                ax[i, j].set_ylabel('Count')

    plt.tight_layout()
    plt.show()

# %%
num_hist_plot(train, kolom_numerik2, 'class')

# %% [markdown]
# Seems like every numerical variabel got outlier. But i kinda confused about do we need to handling this outlier? Because were in Anomaly Detection Project

# %%
for i in categoric_columns:
    print(i, "Memiliki Nilai Unik Sejumlah: ", train[i].nunique())
# Out:
# flag Memiliki Nilai Unik Sejumlah:  11
# protocol_type Memiliki Nilai Unik Sejumlah:  3
# service Memiliki Nilai Unik Sejumlah:  64

# %% [markdown]
# #### One Hot Encoding for Categorical Columns

# %%
train = pd.get_dummies(train,
                       columns=categoric_columns,
                       drop_first=True)

# %%
train.head()
# Out:
#    duration  src_bytes  dst_bytes  land  wrong_fragment  urgent  hot  \
# 0         0        491          0     0               0       0    0
# 1         0        146          0     0               0       0    0
# 2         0        232       8153     0               0       0    0
# 3         0        199        420     0               0       0    0
# 4         0          0          0     0               0       0    0
#
#    num_failed_logins  logged_in  num_compromised  ...  service_systat  \
# 0                  0          0                0  ...           False
# 1                  0          0                0  ...           False
# 2                  0          1                0  ...           False
# 3                  0          1                0  ...           False
# 4                  0          0                0  ...           False
#
#    service_telnet  service_tim_i  service_time  service_urh_i  service_urp_i  \
# ...

# %% [markdown]
# #### Splitting data

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop('class', axis=1), # X
                                                    train['class'], # y
                                                    test_size=0.2,
                                                    stratify=train['class'])

# %%
X_train.shape
# Out:
# (12774, 113)

# %% [markdown]
# #### Feature Scaling
# Feature Scaling to reduce the value so that the data is not too large.

# %%
mm_scaler = MinMaxScaler()
X_train   = mm_scaler.fit_transform(X_train)
X_test    = mm_scaler.transform(X_test)

# %%
X_train[54]
# Out:
# array([0.00000000e+00, 5.87017061e-06, 8.76949556e-06, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.09803922e-01,
#        6.07843137e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e-02, 0.00000000e+00,
#        1.00000000e+00, 9.96078431e-01, 1.00000000e+00, 1.00000000e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
y_train[54]
# Out:
# 'normal'

# %% [markdown]
# #### Dimensionality Reduction with t-SNE (t-Distributed Stochastic Neighbor Embedding)
# untuk mereduksi dimensi data, sehingga data yang memiliki banyak fitur bisa direpresentasikan dalam bentuk yang lebih sederhana, seperti 2D atau 3D. t-SNE menggunakan transformasi non-linear untuk memetakan data ke ruang berdimensi lebih rendah.  t-SNE juga menghitung distribusi probabilitas untuk jarak antar titik dalam ruang berdimensi tinggi dan mencoba meniru distribusi tersebut di ruang berdimensi rendah sehingga mendapatkan hasil representasi dalam ruang berdimensi lebih rendah yang mempertahankan hubungan lokal antar titik data.

# %%
tsne         = TSNE(n_components=3) # n_component = 3 dimensi
X_train_tsne = tsne.fit_transform(X_train)

X_train_tsne.shape
# Out:
# (12774, 3)

# %%
# warna_class  = list(map(lambda x: '#D4FFCA' if x == 'normal' else '#0F333D', y_train))

# # 3 dimension viz

# fig = go.Figure()
# fig.add_trace(go.Scatter3d(x      = X_train_tsne[:, 0],
#                            y      = X_train_tsne[:, 1],
#                            z      = X_train_tsne[:, 2],
#                            mode   = 'markers',
#                            marker = dict(color=warna_class)))
# fig.show()

# %% [markdown]
# Anomali ditunjukan dengan warna scatter plot dengan marker hijau gelap. Sedangkan aktivitas normal ditunjukan dengan warna scatter plot hijau terang. Cukup menandakan adanya perbedaan dan pola

# %%
tsne2         = TSNE(n_components=2) # n_component = 2 dimensi
X_train_tsne2 = tsne2.fit_transform(X_train)

X_train_tsne2.shape
# Out:
# (12774, 2)

# %%
# # 2 dimension viz

# fig = go.Figure()
# fig.add_trace(go.Scatter(x      = X_train_tsne2[:, 0],
#                          y      = X_train_tsne2[:, 1],
#                          mode   = 'markers',
#                          marker = dict(color=warna_class)))
# fig.show()

# %% [markdown]
# Sepertinya kedua kelas anomaly network tersebut memiliki karakteristiknya tersendiri. Dimana data yang digunakan melalui penerapan Dimensionality Reduction menggunakan t-SNE tersebut menunjukkan bahwa kelas network dalam keadaan normal (hijau terang) itu cenderung memiliki nilai yang rendah. Sedangkan data yang anomaly (hijau gelap) itu cenderung nilainya besar.

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:15px;background-color:#0F333D;margin:0;color:#D4FFCA;font-family:Verdana,sans-serif;font-size:9-0%;text-align:center;border-radius: 5px 5px;overflow:hidden;font-weight:900">4. Modeling</p>

# %% [markdown]
# 1. **Extended Isolation Forest** adalah peningkatan dari Isolation Forest yang memperbaiki cara pohon-pohon isolasi dibangun dan dipotong, sehingga meningkatkan kinerja dalam mendeteksi anomali. EIF menggunakan hyperplane (bukan hanya garis) untuk membagi data pada setiap node, yang memungkinkan deteksi anomali yang lebih presisi.
#
# 2. **Local Outlier Factor (LOF)** adalah metode deteksi outlier yang unsupervised dengan menghitung deviasi kepadatan lokal dari suatu titik data dengan tetangganya. LOF membandingkan kepadatan lokal dari suatu titik data dengan kepadatan tetangganya. Jika suatu titik data memiliki kepadatan yang jauh lebih rendah dibandingkan dengan tetangganya, maka titik data tersebut dianggap sebagai outlier.
#
# 3. **DBSCAN (Density-Based Spatial Clustering of Applications with Noise)** adalah algoritma klasterisasi berbasis kepadatan yang tidak memerlukan parameter khusus jumlah klaster. Algoritma ini mengelompokkan titik-titik yang berdekatan dan menandai titik-titik yang berada di wilayah dengan kepadatan rendah sebagai outlier.

# %%
y_train.value_counts()
# Out:
# class
# normal     10759
# anomaly     2015
# Name: count, dtype: int64

# %% [markdown]
# ### Extended Isolation Forest

# %%
forest = iForest(X_train, ntrees=150, sample_size=52, ExtensionLevel=1)

# %%
# prediksi

anomaly_scores_train = forest.compute_paths(X_in=X_train)
threshold_train      = np.percentile(anomaly_scores_train, 95)
y_pred_train_ifo     = np.where(anomaly_scores_train >= threshold_train, 'anomaly', 'normal')

anomaly_scores_test  = forest.compute_paths(X_in=X_test)
threshold_test       = np.percentile(anomaly_scores_test, 95)
y_pred_test_ifo      = np.where(anomaly_scores_test >= threshold_test, 'anomaly', 'normal')

# %%
print("Klasifikasi Anomali Report EIF Terhadap Data Train")
print(classification_report(y_train, y_pred_train_ifo))
# Out:
# Klasifikasi Anomali Report EIF Terhadap Data Train
#               precision    recall  f1-score   support
#
#      anomaly       0.68      0.21      0.33      2015
#       normal       0.87      0.98      0.92     10759
#
#     accuracy                           0.86     12774
#    macro avg       0.77      0.60      0.62     12774
# weighted avg       0.84      0.86      0.83     12774

# %%
print("Klasifikasi Anomali Report EIF Terhadap Data Test")
print(classification_report(y_test, y_pred_test_ifo))
# Out:
# Klasifikasi Anomali Report EIF Terhadap Data Test
#               precision    recall  f1-score   support
#
#      anomaly       0.68      0.22      0.33       504
#       normal       0.87      0.98      0.92      2690
#
#     accuracy                           0.86      3194
#    macro avg       0.78      0.60      0.63      3194
# weighted avg       0.84      0.86      0.83      3194

# %% [markdown]
# Adjusted Rand Index (ARI)
#
# Adjusted Rand Index (ARI) adalah sebuah metrik yang digunakan untuk mengevaluasi kesamaan antara dua klaster atau pengelompokan data. Ini digunakan untuk mengukur kualitas hasil clustering atau pengelompokan data dengan membandingkan dengan label ground truth (label asli).
#
# Adjusted Rand Index (ARI) mengukur kesamaan antara dua klaster (pengelompokan data). Nilai ARI berkisar antara -1 hingga 1:
# - Nilai 1: Hasil clustering identik dengan label asli.
# - Nilai 0: Hasil clustering tidak lebih baik daripada pengelompokan acak.
# - Nilai negatif: Hasil clustering lebih buruk daripada pengelompokan acak.

# %%
# Adjusted Rand Index

adjusted_rand_score(y_train, y_pred_train_ifo), adjusted_rand_score(y_test, y_pred_test_ifo)
# Out:
# (0.22325219322125814, 0.22791215380129634)

# %% [markdown]
# Hasil Klasifikasi Report dan Rand Score menunjukkan performa EIF yang cukup bagus dan tidak menunjukkan adanya overvit? Artinya model mungkin cocok dalam mendeteksi outlier yang merupakan minoritas.

# %% [markdown]
# ### Local Outlier Factor

# %%
lofi = LocalOutlierFactor() # for now im using all the default params

# %%
lofi.fit(X_train)
# Out:
# LocalOutlierFactor()

# %%
y_pred_train_lofi = lofi.fit_predict(X_train)
y_pred_test_lofi  = lofi.fit_predict(X_test)

# %%
#memeriksa output prediksi

np.unique(y_pred_train_lofi, return_counts=True)
# Out:
# (array([-1,  1]), array([ 2387, 10387], dtype=int64))

# %%
y_pred_train_lofi.shape, y_pred_test_lofi.shape
# Out:
# ((12774,), (3194,))

# %%
y_pred_test_lofi
# Out:
# array([ 1, -1,  1, ..., -1,  1,  1])

# %%
y_pred_train_lofi = np.where(y_pred_train_lofi == -1, 'anomaly', 'normal')
y_pred_test_lofi  = np.where(y_pred_test_lofi  == -1, 'anomaly', 'normal')

# %%
print("Klasifikasi Anomali Report LOF Terhadap Data Train")
print(classification_report(y_train, y_pred_train_lofi))
# Out:
# Klasifikasi Anomali Report LOF Terhadap Data Train
#               precision    recall  f1-score   support
#
#      anomaly       0.29      0.35      0.32      2015
#       normal       0.87      0.84      0.86     10759
#
#     accuracy                           0.77     12774
#    macro avg       0.58      0.60      0.59     12774
# weighted avg       0.78      0.77      0.77     12774

# %%
print("Klasifikasi Anomali Report LOF Terhadap Data Test")
print(classification_report(y_test, y_pred_test_lofi))
# Out:
# Klasifikasi Anomali Report LOF Terhadap Data Test
#               precision    recall  f1-score   support
#
#      anomaly       0.35      0.55      0.43       504
#       normal       0.91      0.81      0.86      2690
#
#     accuracy                           0.77      3194
#    macro avg       0.63      0.68      0.64      3194
# weighted avg       0.82      0.77      0.79      3194

# %%
adjusted_rand_score(y_train, y_pred_train_lofi), adjusted_rand_score(y_test, y_pred_test_lofi)
# Out:
# (0.12016149026633066, 0.19368856152046374)

# %% [markdown]
# **Model Local Outlier Factor (LOF)** juga sepertinya memiliki performa yang cukup baik, namun EIF memiliki performa lebih baik jika dilihat dari hasil klasifikasi report dan Rand score.

# %% [markdown]
# ### DBSCAN

# %%
db = DBSCAN() # we still usin the default params

# %%
db.fit(X_train)
# Out:
# DBSCAN()

# %%
y_pred_train_db = db.fit_predict(X_train)
y_pred_test_db  = db.fit_predict(X_test)

# %%
y_pred_train_db.shape, y_pred_test_db.shape
# Out:
# ((12774,), (3194,))

# %%
#np.unique(y_pred_train_db, return_counts=True)

# %%
y_pred_train_db = np.where(y_pred_train_db == -1, 'anomaly', 'normal')
y_pred_test_db  = np.where(y_pred_test_db  == -1, 'anomaly', 'normal')

# %%
adjusted_rand_score(y_train, y_pred_train_db), adjusted_rand_score(y_test, y_pred_test_db)
# Out:
# (0.07648860396936412, 0.19852582500481256)

# %% [markdown]
# #### Seems like based on 3 model above. EIF (Extended Isolation Forest) is the best perform.

# %% [markdown]
# Dalam proyek ini, kita telah menganggap masalah sebagai deteksi anomali. Dimana kelas 'anomaly' merupakan kelas minoritas, sehingga ini data tersebut sangat cocok untuk digunakan dalam algoritma Anomaly Detection. Oleh karena itu, kita sebaiknya mencari algoritma paling cocok dengan parameter terbaik, lalu setelah itu mengevaluasi model dan memvisualisasikannya.
#
# Selain itu, kita menggunakan seluruh set fitur untuk deteksi anomali, yang bukan merupakan ide bagus. Kita perlu menggunakan hanya fitur-fitur penting untuk deteksi anomali.

# %% [markdown]
# ### Feature Selection With RFE

# %%
rfe_forest = RandomForestClassifier() #using default params

# %%
rfe_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfe_forest.feature_importances_
# Out:
# array([4.79872928e-03, 1.26559136e-01, 3.52087299e-02, 2.06531910e-05,
#        7.34627451e-03, 0.00000000e+00, 3.75363799e-03, 3.94050843e-06,
#        1.76778420e-02, 2.01479398e-03, 9.27982359e-06, 3.59609282e-05,
#        3.58921544e-04, 1.52341387e-04, 1.89732868e-07, 3.93560004e-05,
#        0.00000000e+00, 0.00000000e+00, 7.58982323e-04, 4.25179868e-02,
#        2.38722561e-02, 4.40067100e-02, 3.16026695e-02, 1.45581905e-02,
#        8.11733615e-03, 4.16723586e-02, 5.02529398e-02, 3.98240015e-03,
#        2.89300107e-02, 2.35769533e-02, 3.91514805e-02, 3.30036026e-02,
#        2.01405243e-02, 1.69566018e-02, 5.26309893e-02, 9.24039755e-02,
#        1.63674523e-02, 1.46775330e-02, 4.70925121e-03, 3.93300500e-04,
#        6.00507308e-05, 2.88347678e-03, 5.00399076e-02, 4.35688762e-04,
#        3.14089174e-05, 5.62243295e-05, 5.72617609e-02, 3.43604257e-04,
#        1.00259698e-02, 9.75241882e-03, 1.50446799e-04, 3.72675716e-08,
# ...

# %%
# choose top 42 feature

jumlah_fitur      = 42

fitur_rfe_penting = rfe_forest.feature_importances_
fitur_rfe_penting = fitur_rfe_penting.argsort()[::-1][:jumlah_fitur]

# %%
fitur_rfe_penting, rfe_forest.feature_importances_[fitur_rfe_penting]
# Out:
# (array([ 1, 35, 46, 34, 26, 42, 21, 19, 25, 30,  2, 31, 22, 28, 20, 29, 32,
#          8, 33, 36, 63, 71, 37, 23, 93, 62, 48, 49, 24,  4,  0, 38, 27,  6,
#         68, 41,  9, 89, 66, 98, 60, 18], dtype=int64),
#  array([0.12655914, 0.09240398, 0.05726176, 0.05263099, 0.05025294,
#         0.05003991, 0.04400671, 0.04251799, 0.04167236, 0.03915148,
#         0.03520873, 0.0330036 , 0.03160267, 0.02893001, 0.02387226,
#         0.02357695, 0.02014052, 0.01767784, 0.0169566 , 0.01636745,
#         0.01590145, 0.01485149, 0.01467753, 0.01455819, 0.0141869 ,
#         0.01142549, 0.01002597, 0.00975242, 0.00811734, 0.00734627,
#         0.00479873, 0.00470925, 0.0039824 , 0.00375364, 0.00290452,
#         0.00288348, 0.00201479, 0.00119887, 0.00104808, 0.00098082,
#         0.00088508, 0.00075898]))

# %%
X_train_rfe = X_train[:, fitur_rfe_penting]
X_test_rfe  = X_test[:, fitur_rfe_penting]

# %%
X_train_rfe.shape
# Out:
# (12774, 42)

# %%
X_test_rfe.shape
# Out:
# (3194, 42)

# %% [markdown]
# ### Hyperparameter on EIF & LOF Algorithm

# %%
from sklearn.model_selection import RandomizedSearchCV

parameter_eif = {'ntrees': [150, 200, 250],
                 'sample_size': [52, 64, 80],
                 'ExtensionLevel': [1, 2, 3]}

# %%
# for ntrees in parameter_eif['ntrees']:
#     for sample_size in parameter_eif['sample_size']:
#         for ExtensionLevel in parameter_eif['ExtensionLevel']:
            
#             forest = iForest(X_train_rfe,
#                              ntrees=ntrees,
#                              sample_size=sample_size,
#                              ExtensionLevel=ExtensionLevel)
            
#             anomaly_scores_test = forest.compute_paths(X_in=X_test_rfe)
#             threshold_test      = np.percentile(anomaly_scores_test, 95)
#             y_pred_test_ifo     = np.where(anomaly_scores_test >= threshold_test, 'anomaly', 'normal')
            
#             print(f"ntrees: {ntrees}, sample_size: {sample_size}, ExtensionLevel: {ExtensionLevel}")
#             print(classification_report(y_test, y_pred_test_ifo))
#             print()

# %% [markdown]
# ntrees: 200, sample_size: 64, ExtensionLevel: 1
#
#
#               precision    recall  f1-score   support
#
#      anomaly       0.69      0.22      0.33       504
#       normal       0.87      0.98      0.92      2690
#
#     accuracy                           0.86      3194
#    macro avg       0.78      0.60      0.63      3194
# weighted avg       0.84      0.86      0.83      3194

# %%
forest_best               = iForest(X_train_rfe,
                                    ntrees=200,
                                    sample_size=64,
                                    ExtensionLevel=1)

anomaly_scores_train_best = forest_best.compute_paths(X_in=X_train_rfe)
threshold_train_best      = np.percentile(anomaly_scores_train_best, 95)
y_pred_train_ifo_best     = np.where(anomaly_scores_train_best >= threshold_train_best, 'anomaly', 'normal')

anomaly_scores_test_best  = forest_best.compute_paths(X_in=X_test_rfe)
threshold_test_best       = np.percentile(anomaly_scores_test_best, 95)
y_pred_test_ifo_best      = np.where(anomaly_scores_test_best >= threshold_test_best, 'anomaly', 'normal')

print(classification_report(y_train, y_pred_train_ifo_best))
# Out:
#               precision    recall  f1-score   support
#
#      anomaly       0.66      0.21      0.32      2015
#       normal       0.87      0.98      0.92     10759
#
#     accuracy                           0.86     12774
#    macro avg       0.76      0.59      0.62     12774
# weighted avg       0.84      0.86      0.83     12774

# %%
param_lof = {'n_neighbors': [5, 10, 20, 30, 40],
             'leaf_size': [20, 30, 40, 50],
             'metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski']}

# %%
def lof_skor(estimator, X):
    y_pred = estimator.fit_predict(X)
    y_true = y_train
    y_pred = np.where(y_pred == -1, 1, 0) # -1 artinya anomaly dan 0 itu normal
    
    return f1_score(y_true, y_pred, pos_label=1)

# %%
skor_lof   = make_scorer(lof_skor, greater_is_better=True)
lof        = LocalOutlierFactor()

# %%
random_lof = RandomizedSearchCV(estimator=lof,
                                param_distributions=param_lof,
                                cv=5,
                                scoring=skor_lof,
                                n_iter=10)
random_lof.fit(X_train_rfe)
# Out:
# RandomizedSearchCV(cv=5, estimator=LocalOutlierFactor(),
#                    param_distributions={'leaf_size': [20, 30, 40, 50],
#                                         'metric': ['euclidean', 'manhattan',
#                                                    'chebyshev', 'minkowski'],
#                                         'n_neighbors': [5, 10, 20, 30, 40]},
#                    scoring=make_scorer(lof_skor, response_method='predict'))

# %%
print("Parameter Best LOF: ", random_lof.best_params_)
# Out:
# Parameter Best LOF:  {'n_neighbors': 40, 'metric': 'chebyshev', 'leaf_size': 40}

# %%
best_lof               = random_lof.best_estimator_
y_pred_train_lofi_best = best_lof.fit_predict(X_train_rfe)
y_pred_test_lofi_best  = best_lof.fit_predict(X_test_rfe)

y_pred_train_lofi_best = np.where(y_pred_train_lofi_best == -1, 'anomaly', 'normal')
y_pred_test_lofi_best  = np.where(y_pred_test_lofi_best  == -1, 'anomaly', 'normal')

# %%
print(classification_report(y_test, y_pred_test_lofi_best))
# Out:
#               precision    recall  f1-score   support
#
#      anomaly       0.23      0.44      0.30       504
#       normal       0.87      0.73      0.80      2690
#
#     accuracy                           0.68      3194
#    macro avg       0.55      0.58      0.55      3194
# weighted avg       0.77      0.68      0.72      3194

# %% [markdown]
# #### Since the recall is kinda low, this time ill try binary classification

# %%
random_forest_rfe = RandomForestClassifier()

# %%
random_forest_rfe.fit(X_train_rfe, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_tr_rf_rfe = random_forest_rfe.predict(X_train_rfe)
y_pred_tt_rf_rfe = random_forest_rfe.predict(X_test_rfe)

# %%
print("Klasifikasi Anomali Report Random Forest Terhadap Data Test")
print(classification_report(y_test, y_pred_tt_rf_rfe))
# Out:
# Klasifikasi Anomali Report Random Forest Terhadap Data Test
#               precision    recall  f1-score   support
#
#      anomaly       1.00      0.99      1.00       504
#       normal       1.00      1.00      1.00      2690
#
#     accuracy                           1.00      3194
#    macro avg       1.00      1.00      1.00      3194
# weighted avg       1.00      1.00      1.00      3194

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:15px;background-color:#0F333D;margin:0;color:#D4FFCA;font-family:Verdana,sans-serif;font-size:9-0%;text-align:center;border-radius: 5px 5px;overflow:hidden;font-weight:900">5. Evaluation</p>

# %%
tsne          = TSNE(n_components=3, random_state=42)
X_test_rfe_3d = tsne.fit_transform(X_test_rfe)

# %%
anomaly_data = X_test_rfe_3d[y_pred_test_ifo_best == 'anomaly']
normal_data = X_test_rfe_3d[y_pred_test_ifo_best == 'normal']

fig = go.Figure(data=[
    go.Scatter3d(
        x=anomaly_data[:, 0], y=anomaly_data[:, 1], z=anomaly_data[:, 2],
        mode='markers',
        marker=dict(size=4, color='red', opacity=0.8),
        name='Anomaly'
    ),
    go.Scatter3d(
        x=normal_data[:, 0], y=normal_data[:, 1], z=normal_data[:, 2],
        mode='markers',
        marker=dict(size=4, color='blue', opacity=0.8),
        name='Normal'
    )
])

fig.update_layout(
    margin=dict(l=0, r=0, b=0, t=0),
    title="3D Scatter Plot of Anomalies and Normal Data using t-SNE"
)

fig.show()
# Out:
# <div>                            <div id="437478e5-bfa4-48bc-aec3-860b77d7113e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("437478e5-bfa4-48bc-aec3-860b77d7113e")) {                    Plotly.newPlot(                        "437478e5-bfa4-48bc-aec3-860b77d7113e",                        [{"marker":{"color":"red","opacity":0.8,"size":4},"mode":"markers","name":"Anomaly","x":[9.779631614685059,5.6925225257873535,8.4107666015625,4.745365142822266,-0.15543551743030548,5.1273112297058105,5.702948570251465,8.986320495605469,8.981163024902344,5.120378494262695,2.4126102924346924,9.708709716796875,10.24881649017334,5.499680042266846,12.720148086547852,-2.167651891708374,6.0192341804504395,-0.4985332190990448,-2.390756845474243,6.531835079193115,9.6674795
# ...

# %% [markdown]
# Visualisasi 3D scatter plot dari data X_test_rfe yang telah diterapkan t-SNE ke dalam 3 dimensi dan hasil prediksi menggunakan **iForest** menunjukkan bahwa sebagian besar data normal (ditandai dengan warna biru) terdistribusi merata dan mengelompok dengan baik, sementara data anomali (ditandai dengan warna merah) terkonsentrasi di beberapa area terpisah namun hampir keseluruhan data anomali berada ketika nilai Z cukup tinggi dan nilai X dan Y yang rendah (sekitar 0), menunjukkan kemampuan model iForest dalam mendeteksi anomali yang berbeda secara signifikan dari pola normal. Beberapa anomali terletak jauh dari cluster normal, menandakan adanya anomali yang jelas dan berbeda, sementara beberapa anomali yang dekat dengan data normal menunjukkan tantangan dalam klasifikasi.

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:15px;background-color:#0F333D;margin:0;color:#D4FFCA;font-family:Verdana,sans-serif;font-size:9-0%;text-align:center;border-radius: 5px 5px;overflow:hidden;font-weight:900">6. Deploy</p>

# %% [markdown]
# #### I'll try deploy this model to streamlit soon
# but, it will be kinda complex form since were using 42 variabel to input the data.

# %%
import pickle

path = 'C:/Users/ASUS/kode/projek/19. Anomaly Detection/'

with open(path + 'mm_scaler.pkl', 'wb') as file:
    pickle.dump(mm_scaler, file)

with open(path + 'ExtendedIForest_best.pkl', 'wb') as file:
    pickle.dump(forest_best, file)

with open(path + 'random_forest_rfe.pkl', 'wb') as file:
    pickle.dump(random_forest_rfe, file)
